# %%
from KID import KID
import numpy as np
import matplotlib.pyplot as plt

# %%
k = KID(Qc = 1.4e5, hw0 = 19.955, kbT = 17.9, V = 12.36)
lph = .420 #µm

# %%
kbTarr = np.linspace(.12,.3,5)*86.17
for kbT in kbTarr:
    k.kbT = kbT
    k.plot_dAthetaresp(2*np.pi*3e5/lph,tStop = 2.5e6,plot='theta')
    plt.yscale('log')
plt.legend(kbTarr)

# %%
for kbT in kbTarr:
    k.kbT = kbT
    k.plot_dAthetaresp(2*np.pi*3e5/lph,tStop = 2.5e6,plot='theta')
    plt.yscale('log')
plt.legend(kbTarr)
