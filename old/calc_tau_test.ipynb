# %%
import numpy as np
import matplotlib.pyplot as plt
import datacalc
import kidcalc

# %%
KIDnum = 1
Pread = [92, 96]#, 100, 104]
wvlngth = 1545
Tbath = 200

# %%
for i in range(len(Pread)):
    plt.figure()
    print(datacalc.tau(KIDnum,Pread[i],Tbath,1,1e4,plot=True))
# Out:
# (0.0003233013943466194, 13.799174840750618)
# (0.0002822699300842427, 28.684903031362108)

# %%
S21data = datacalc.get_S21data(KIDnum,96)
plt.plot(S21data[:,1])
