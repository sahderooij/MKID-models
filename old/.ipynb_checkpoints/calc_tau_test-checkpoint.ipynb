# %%
import numpy as np
import matplotlib.pyplot as plt
import datacalc
import kidcalc

# %%
KIDnum = 6
Pread = [92, 96, 100, 104]
wvlngth = 673
Tbath = 120

# %%
for i in range(len(Pread)):
    plt.figure()
    print(datacalc.tau(KIDnum,Pread[i],Tbath,1,1e4,plot=True))
# Out:
# (0.000984573888958278, 2.682805726678993)
# (0.0006116410493287168, 8.205756694462389)
# (0.0003202932279716783, 187.443384527852)
# (0.04156866296486922, 5.693514222788211)

# %%
S21data = datacalc.get_S21data(KIDnum,96)
plt.plot(S21data[:,1])
