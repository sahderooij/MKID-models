# %%
from KID import KID
import numpy as np
import matplotlib.pyplot as plt

# %%
k = KID()

# %%
Qcarr = np.logspace(3,5,5)
for Qc in Qcarr:
    k.Qc = Qc
    dNqp = .6582*3e8/1000/k.D_0
    k.plot_dAthetaresp(k.Nqp_0 + dNqp,tStop = .5e10,plot='theta')
    plt.yscale('log')
plt.legend(Qcarr)

# %%
Qcarr = np.logspace(3,5,5)
for Qc in Qcarr:
    k.Qc = Qc
    dNqp = .6582*3e8/1000/k.D_0
    k.plot_dAthetaresp(k.Nqp_0 + dNqp,tStop = .5e10,plot='dA')
plt.legend(Qcarr)
