# %%
from KID import KID
import numpy as np
import matplotlib.pyplot as plt

# %%
k = KID()

# %%
akarr = np.linspace(.1,.9,5)
for ak in akarr:
    k.ak = ak
    dNqp = .6582*3e8/1000/k.D_0
    k.plot_dAthetaresp(k.Nqp_0 + dNqp,tStop = .5e10,plot='theta')
plt.legend(akarr)

# %%
akarr = np.linspace(.1,.9,5)
for ak in akarr:
    k.ak = ak
    dNqp = .6582*3e8/100000/k.D_0
    k.plot_dAthetaresp(k.Nqp_0 + dNqp,tStop = .5e10,plot='dA')
plt.legend(akarr)

# %%
k.Nqp_0
# Out:
# 9.713010024841042

# %%
dNqp
# Out:
# 11.130566888346161
