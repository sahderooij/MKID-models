# %%
import numpy as np
import matplotlib.pyplot as plt
import datacalc
import importlib

# %%
importlib.reload(datacalc)
np.seterr(over='raise')
k = datacalc.init_KID('LT165',2,85,250,Teffmethod='GR')
# Out:
# C:\Users\Steven\Google Drive\AP\Thesis\Coding\kidcalc.py:51: UserWarning: This takes long..
#   warnings.warn('This takes long..')
# ---------------------------------------------------------------------------
# FloatingPointError                        Traceback (most recent call last)
# <ipython-input-1-63383cccdde9> in <module>
#       3 import datacalc
#       4 np.seterr(over='raise')
# ----> 5 k = datacalc.init_KID('LT165',2,85,250,Teffmethod='GR')
#
# ~\Google Drive\AP\Thesis\Coding\datacalc.py in init_KID(Chipnum, KIDnum, Pread, Tbath, Teffmethod, wvl, traps)
#     454     d = S21data[0, 25]
#     455     kbTc = S21data[0,21] * 86.17
# --> 456     ak1 = ak(S21data)[0]
#     457
#     458     tesc1 = tesc(Chipnum,KIDnum)
#
# ~\Google Drive\AP\Thesis\Coding\datacalc.py in ak(S21data, lbd0, N0, kbTD, plot, reterr, method)
#     217     x = np.zeros(len(y))
#     218     i = 0
# --> 219     s0 = cinduct(hw0, D(kbT[0], N0, Vsc, kbTD), kbT[0])
#     220     for kbTi in kbT[mask]:
# ...

# %%
k.plot_resp(6.528e-4*2*np.pi*3e8/(402*1e-3))
# Out:
# ---------------------------------------------------------------------------
# FloatingPointError                        Traceback (most recent call last)
# <ipython-input-12-d09b77018c58> in <module>
# ----> 1 k.plot_resp(6.528e-4*2*np.pi*3e8/(402*1e-3))
#
# ~\Google Drive\AP\Thesis\Coding\KID.py in plot_resp(self, hwrad, tStop, tInc, points)
#     319
#     320         plt.figure(1, figsize=(5, 5))
# --> 321         self.plot_freqsweep()
#     322         ts, S21, dAtheta = self.calc_respt(hwrad, tStop, tInc, points)
#     323         plt.plot(np.real(S21), np.imag(S21), '.b')
#
# ~\Google Drive\AP\Thesis\Coding\KID.py in plot_freqsweep(self, start, stop, points)
#     241 # Plot functions
#     242     def plot_freqsweep(self, start=None, stop=None, points=50):
# --> 243         hwread = self.hwread
#     244         D_0 = self.D0
#     245         s20 = self.s20
#
# ~\Google Drive\AP\Thesis\Coding\KID.py in hwread(self)
#      52     def hwread(self):
# ...
